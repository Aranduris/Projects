# %%
# Base Imports
import numpy as np
import pandas as pd
import os
import warnings
warnings.filterwarnings('ignore')
# Train test split and performance measures
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score,accuracy_score
# class balancing
from sklearn.utils.class_weight import compute_sample_weight
# SVD and scaler
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler
# Tensorflow model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Bidirectional, Dropout, LSTM

# %%
Names = pd.read_csv("C:/Users/ritwi/OneDrive/Documents/MS_DataScience/Thesis/Project/Data/Sample/sample_function.csv")
Names = Names.drop('t_tax_seq_id', axis=1)
Names = Names.drop_duplicates()

# %%
Function = pd.read_csv("C:/Users/ritwi/OneDrive/Documents/MS_DataScience/Thesis/Project/Data/Sample/sample_function.csv")
Function = Function.drop('go_function',axis=1)
final_table_columns = ['GO:0008150','GO:0005488','GO:0003824','GO:0005515',
                       'GO:0005575','GO:0008152','GO:0009987','GO:0003674',
                       'GO:0110165','GO:0071704']
Function = Function[Function['go_go_id'].isin(final_table_columns)]

# %%
one_hot_encoded = pd.get_dummies(Function, columns=['go_go_id'])
one_hot_encoded = one_hot_encoded.groupby('t_tax_seq_id').sum().reset_index()
one_hot_encoded.columns = one_hot_encoded.columns.str.replace('go_go_id_', '')

# %%
Seq = pd.read_csv("C:/Users/ritwi/OneDrive/Documents/MS_DataScience/Thesis/Project/Data/Sample/sample.csv")
Seq = Seq.drop('tax_id',axis=1)

# %%
Merge_df = pd.merge(Seq, one_hot_encoded, left_on='tax_seq_id', right_on='t_tax_seq_id', how='inner')

# %%
Merge_df = Merge_df.drop(columns=['t_tax_seq_id'])
Merge_df.set_index('tax_seq_id', inplace=True)
#Merge_df['seq_length'] = Merge_df['seq'].apply(lambda x: len(str(x)))
#Merge_df = Merge_df[Merge_df['seq_length']<=500]
#Merge_df = Merge_df.drop(columns=['seq_length'])

# %%
X = Merge_df.drop(columns=Merge_df.columns[1:])
Y = Merge_df.drop(columns=Merge_df.columns[0])
total_words = 24

# %%
max_length_column1 = 500

# %%
len(X)
# Out:
# 3131

# %%
def tokenized(sequence):
    tokenizer = {'A': 1,'C': 2,'D': 3,'E': 4,'F': 5,'G': 6,
               'H': 7,'I': 8,'K': 9,'L': 10,'M': 11,'N': 12,
               'P': 13,'Q': 14,'R': 15,'S': 16,'T': 17,
               'V': 18,'W': 19,'Y': 20, 'O':21, 'U':22, 'Z':23}
    sequence_values = []
    for i, letter in enumerate(sequence):
        if i < 500 and letter in tokenizer:
            sequence_values.append(tokenizer[letter])
    return sequence_values

# %%
def n_gramer(seq_list,max_length_column1):
    result_list_of_lists = [[0] * (len(seq_list) - j - 1) + seq_list[:j + 1] for j in range(len(seq_list))]
    padded = padding(result_list_of_lists,max_length_column1)
    padded = np.array(padded)
    return padded

# %%
def padding(result_list_of_lists,max_length):
    result_2d_array = [sublist + [0] * (max_length - len(sublist)) for sublist in result_list_of_lists]
    return result_2d_array

# %%
for index, row in X.iterrows():
    seq = row['seq']
    temp = tokenized(seq)
    temp = n_gramer(temp, max_length_column1)
    row['seq'] = temp

# %%
# Convert Data to a 3D array
def three_d_array(df):
    num_samples = len(df)
    max_rows = df['seq'].apply(lambda arr: arr.shape[0]).max()
    num_columns = df['seq'].iloc[0].shape[1]
    result = np.full((num_samples, max_rows, num_columns), np.nan)
    for i, seq in enumerate(df['seq']):
        start_row = max_rows - seq.shape[0]
        result[i, start_row:, :] = seq
    return result

# %%
new_X = three_d_array(X)
new_X = np.nan_to_num(new_X)

# %%
def S_V_D(X):
    n_components = 28
    X = StandardScaler().fit_transform(X)
    tsvd = TruncatedSVD(n_components=n_components)
    reduced_array = tsvd.fit_transform(X)
    reduced_array = reduced_array.T
    reduced_array = tsvd.fit_transform(reduced_array)
    reduced_array = reduced_array.T
    return reduced_array

# %%
reduced_X = np.empty((3131, 28, 28))
for i, row in enumerate(new_X):
    temp = row
    temp = S_V_D(temp)
    reduced_X[i] = temp

# %%
X_train, X_test, y_train, y_test = train_test_split(reduced_X, Y, test_size=0.2)

# %%
model = Sequential()
model.add(Bidirectional(LSTM(24, input_shape=(new_X.shape[1:]),activation='tanh',return_sequences=True)))
model.add(Dropout(0.5))
model.add(LSTM(32,activation='tanh'))
model.add(Dropout(0.5))
model.add(Dense(16,activation='tanh'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=[tf.keras.metrics.BinaryAccuracy()])

# %%
Records = pd.DataFrame(columns=['Go-Ids', 'F1-Score','Accuracy'])
for column in y_train.columns:
    temp = []
    a = y_train[column]
    b = y_test[column]
    sample_weights = compute_sample_weight(class_weight='balanced', y=a)
    history = model.fit(X_train,a,epochs=10,sample_weight =sample_weights)
    #history = model.fit(X_train,a,epochs=10)
    y_pred = model.predict(X_test)
    y_pred = [0 if value < 0.5 else 1 for value in y_pred]
    temp.append(column)
    temp.append(f1_score(b, y_pred, average='binary'))
    temp.append(accuracy_score(b,y_pred))
    Records.loc[len(Records)] = temp
# Out:
# Epoch 1/10
# 79/79 [==============================] - 4s 9ms/step - loss: 0.6880 - binary_accuracy: 0.5743
# Epoch 2/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6675 - binary_accuracy: 0.6202
# Epoch 3/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6625 - binary_accuracy: 0.6494
# Epoch 4/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6583 - binary_accuracy: 0.6725
# Epoch 5/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6534 - binary_accuracy: 0.6721
# Epoch 6/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6582 - binary_accuracy: 0.6581
# Epoch 7/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6555 - binary_accuracy: 0.6857
# Epoch 8/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6570 - binary_accuracy: 0.6530
# Epoch 9/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6559 - binary_accuracy: 0.6893
# Epoch 10/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6539 - binary_accuracy: 0.6625
# 20/20 [==============================] - 1s 4ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 11ms/step - loss: 0.6368 - binary_accuracy: 0.5982
# Epoch 2/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6323 - binary_accuracy: 0.6026
# Epoch 3/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6276 - binary_accuracy: 0.6062
# Epoch 4/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6259 - binary_accuracy: 0.6098
# Epoch 5/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6252 - binary_accuracy: 0.6046
# Epoch 6/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6270 - binary_accuracy: 0.5998
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6236 - binary_accuracy: 0.6138
# Epoch 8/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6250 - binary_accuracy: 0.6114
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6223 - binary_accuracy: 0.6074
# Epoch 10/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6208 - binary_accuracy: 0.6158
# 20/20 [==============================] - 0s 4ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6999 - binary_accuracy: 0.4784
# Epoch 2/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6826 - binary_accuracy: 0.4748
# Epoch 3/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6800 - binary_accuracy: 0.4908
# Epoch 4/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6810 - binary_accuracy: 0.4792
# Epoch 5/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6795 - binary_accuracy: 0.4860
# Epoch 6/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6772 - binary_accuracy: 0.4864
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6782 - binary_accuracy: 0.5172
# Epoch 8/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6753 - binary_accuracy: 0.5371
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6755 - binary_accuracy: 0.5236
# Epoch 10/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6753 - binary_accuracy: 0.5276
# 20/20 [==============================] - 0s 4ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6799 - binary_accuracy: 0.4641
# Epoch 2/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6814 - binary_accuracy: 0.4996
# Epoch 3/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6805 - binary_accuracy: 0.4688
# Epoch 4/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6784 - binary_accuracy: 0.4912
# Epoch 5/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6778 - binary_accuracy: 0.5288
# Epoch 6/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6761 - binary_accuracy: 0.5088
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6807 - binary_accuracy: 0.4609
# Epoch 8/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6781 - binary_accuracy: 0.4892
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6764 - binary_accuracy: 0.5108
# Epoch 10/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6757 - binary_accuracy: 0.5268
# 20/20 [==============================] - 0s 4ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6829 - binary_accuracy: 0.6609
# Epoch 2/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6650 - binary_accuracy: 0.6769
# Epoch 3/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6619 - binary_accuracy: 0.6761
# Epoch 4/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6646 - binary_accuracy: 0.6757
# Epoch 5/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6604 - binary_accuracy: 0.6897
# Epoch 6/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6599 - binary_accuracy: 0.6717
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6555 - binary_accuracy: 0.6941
# Epoch 8/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6620 - binary_accuracy: 0.6741
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6588 - binary_accuracy: 0.6933
# Epoch 10/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6598 - binary_accuracy: 0.6797
# 20/20 [==============================] - 0s 4ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.7045 - binary_accuracy: 0.4872
# Epoch 2/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6942 - binary_accuracy: 0.4940
# Epoch 3/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6937 - binary_accuracy: 0.5068
# Epoch 4/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6919 - binary_accuracy: 0.4944
# Epoch 5/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6925 - binary_accuracy: 0.5220
# Epoch 6/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6914 - binary_accuracy: 0.5244
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6934 - binary_accuracy: 0.5048
# Epoch 8/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6936 - binary_accuracy: 0.5080
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6939 - binary_accuracy: 0.5012
# Epoch 10/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6915 - binary_accuracy: 0.5427
# 20/20 [==============================] - 0s 4ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6658 - binary_accuracy: 0.5599
# Epoch 2/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6387 - binary_accuracy: 0.5795
# Epoch 3/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6438 - binary_accuracy: 0.5619
# Epoch 4/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6375 - binary_accuracy: 0.5739
# Epoch 5/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6343 - binary_accuracy: 0.5727
# Epoch 6/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6352 - binary_accuracy: 0.5747
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6307 - binary_accuracy: 0.5946
# Epoch 8/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6345 - binary_accuracy: 0.5755
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6312 - binary_accuracy: 0.5859
# Epoch 10/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6272 - binary_accuracy: 0.5811
# 20/20 [==============================] - 0s 4ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6667 - binary_accuracy: 0.5587
# Epoch 2/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6602 - binary_accuracy: 0.5575
# Epoch 3/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6577 - binary_accuracy: 0.5395
# Epoch 4/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6616 - binary_accuracy: 0.5715
# Epoch 5/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6602 - binary_accuracy: 0.5687
# Epoch 6/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6561 - binary_accuracy: 0.5783
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6542 - binary_accuracy: 0.5823
# Epoch 8/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6651 - binary_accuracy: 0.5439
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6568 - binary_accuracy: 0.5715
# Epoch 10/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6528 - binary_accuracy: 0.5946
# 20/20 [==============================] - 0s 4ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6257 - binary_accuracy: 0.5727
# Epoch 2/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6276 - binary_accuracy: 0.6010
# Epoch 3/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6197 - binary_accuracy: 0.6022
# Epoch 4/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6230 - binary_accuracy: 0.5779
# Epoch 5/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6144 - binary_accuracy: 0.6026
# Epoch 6/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6207 - binary_accuracy: 0.6022
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6164 - binary_accuracy: 0.6110
# Epoch 8/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6159 - binary_accuracy: 0.6106
# Epoch 9/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6170 - binary_accuracy: 0.6130
# Epoch 10/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6140 - binary_accuracy: 0.6182
# 20/20 [==============================] - 0s 4ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7287 - binary_accuracy: 0.4569
# Epoch 2/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6747 - binary_accuracy: 0.6985
# Epoch 3/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6587 - binary_accuracy: 0.6937
# Epoch 4/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6568 - binary_accuracy: 0.6733
# Epoch 5/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6542 - binary_accuracy: 0.7276
# Epoch 6/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6493 - binary_accuracy: 0.7069
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6487 - binary_accuracy: 0.7276
# Epoch 8/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6502 - binary_accuracy: 0.6953
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6466 - binary_accuracy: 0.7181
# Epoch 10/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6494 - binary_accuracy: 0.7081
# 20/20 [==============================] - 0s 4ms/step

# %%
Records = Records.merge(Names, left_on='Go-Ids', right_on='go_go_id')
Records = Records.drop(columns=['go_go_id'])

# %%
Records =  Records.iloc[:,[0,3,1,2]]

# %%
Records =  Records.sort_values(by=['F1-Score','Accuracy'], ascending=False)
Records
# Out:
#        Go-Ids                          go_function  F1-Score  Accuracy
# 0  GO:0003674                   molecular_function  0.783370  0.684211
# 1  GO:0003824                   catalytic activity  0.580645  0.626794
# 6  GO:0008152                    metabolic process  0.487603  0.604466
# 8  GO:0071704  organic substance metabolic process  0.470588  0.555024
# 2  GO:0005488                              binding  0.448567  0.478469
# 7  GO:0009987                     cellular process  0.422764  0.547049
# 5  GO:0008150                   biological_process  0.393195  0.488038
# 9  GO:0110165           cellular anatomical entity  0.359862  0.704944
# 4  GO:0005575                   cellular_component  0.339869  0.677831
# 3  GO:0005515                      protein binding  0.330935  0.555024
