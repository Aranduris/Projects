# %%
# Base Imports
import numpy as np
import pandas as pd
import os
import warnings
warnings.filterwarnings('ignore')
# Train test split and performance measures
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score,accuracy_score
# class balancing
from sklearn.utils.class_weight import compute_sample_weight
# SVD and scaler
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler
# Tensorflow model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Bidirectional, Dropout, LSTM

# %%
Names = pd.read_csv("C:/Users/ritwi/OneDrive/Documents/MS_DataScience/Thesis/Project/Data/Sample/sample_function.csv")
Names = Names.drop('t_tax_seq_id', axis=1)
Names = Names.drop_duplicates()

# %%
Function = pd.read_csv("C:/Users/ritwi/OneDrive/Documents/MS_DataScience/Thesis/Project/Data/Sample/sample_function.csv")
Function = Function.drop('go_function',axis=1)
final_table_columns = ['GO:0008150','GO:0005488','GO:0003824','GO:0005515',
                       'GO:0005575','GO:0008152','GO:0009987','GO:0003674',
                       'GO:0110165','GO:0071704']
Function = Function[Function['go_go_id'].isin(final_table_columns)]

# %%
one_hot_encoded = pd.get_dummies(Function, columns=['go_go_id'])
one_hot_encoded = one_hot_encoded.groupby('t_tax_seq_id').sum().reset_index()
one_hot_encoded.columns = one_hot_encoded.columns.str.replace('go_go_id_', '')

# %%
Seq = pd.read_csv("C:/Users/ritwi/OneDrive/Documents/MS_DataScience/Thesis/Project/Data/Sample/sample.csv")
Seq = Seq.drop('tax_id',axis=1)

# %%
Merge_df = pd.merge(Seq, one_hot_encoded, left_on='tax_seq_id', right_on='t_tax_seq_id', how='inner')

# %%
Merge_df = Merge_df.drop(columns=['t_tax_seq_id'])
Merge_df.set_index('tax_seq_id', inplace=True)
#Merge_df['seq_length'] = Merge_df['seq'].apply(lambda x: len(str(x)))
#Merge_df = Merge_df[Merge_df['seq_length']<=500]
#Merge_df = Merge_df.drop(columns=['seq_length'])

# %%
X = Merge_df.drop(columns=Merge_df.columns[1:])
Y = Merge_df.drop(columns=Merge_df.columns[0])
total_words = 24

# %%
max_length_column1 = 500

# %%
len(X)
# Out:
# 3131

# %%
def tokenized(sequence):
    tokenizer = {'A': 1,'C': 2,'D': 3,'E': 4,'F': 5,'G': 6,
               'H': 7,'I': 8,'K': 9,'L': 10,'M': 11,'N': 12,
               'P': 13,'Q': 14,'R': 15,'S': 16,'T': 17,
               'V': 18,'W': 19,'Y': 20, 'O':21, 'U':22, 'Z':23}
    sequence_values = []
    for i, letter in enumerate(sequence):
        if i < 500 and letter in tokenizer:
            sequence_values.append(tokenizer[letter])
    return sequence_values

# %%
def range_finder(seq_list):
    mapper = {1:[1,8,10,11,18],2:[5,19,20],3:[12,2,14,16,17],
              4:[3,4],5:[15,7,9],6:[6,13],7:[21,22,23]}
    result = []
    current_group = []
    current_group_number = None
    for number in seq_list:
        for group_number, group_elements in mapper.items():
            if number in group_elements:
                if group_number != current_group_number:
                    if current_group:
                        result.append(current_group)
                    current_group = [number]
                    current_group_number = group_number
                else:
                    current_group.append(number)
                break
        else:
            if current_group:
                result.append(current_group)
            current_group = []
            current_group_number = None
    if current_group:
        result.append(current_group)
    return result

# %%
def n_gramer(seq_list,max_length_column1):
    input_sequence = []
    temp = []
    rang = range_finder(seq_list)
    for sublist in rang:
        temp.extend(sublist)
        input_sequence.append(temp.copy())
    input_sequence = padding(input_sequence,max_length_column1)
    return input_sequence

# %%
def padding(input_seq,max_length_column1):
    max_length = max_length_column1
    padded_array = np.zeros((len(input_seq), max_length))
    for i, row in enumerate(input_seq):
        start_index = max_length - len(row)
        padded_array[i, start_index:] = row
    return padded_array

# %%
for index, row in X.iterrows():
    seq = row['seq']
    temp = tokenized(seq)
    temp = n_gramer(temp, max_length_column1)
    row['seq'] = temp

# %%
# Convert Data to a 3D array
def three_d_array(df):
    num_samples = len(df)
    max_rows = df['seq'].apply(lambda arr: arr.shape[0]).max()
    num_columns = df['seq'].iloc[0].shape[1]
    result = np.full((num_samples, max_rows, num_columns), np.nan)
    for i, seq in enumerate(df['seq']):
        start_row = max_rows - seq.shape[0]
        result[i, start_row:, :] = seq
    return result

# %%
new_X = three_d_array(X)
new_X = np.nan_to_num(new_X)

# %%
def S_V_D(X):
    n_components = 28
    X = StandardScaler().fit_transform(X)
    tsvd = TruncatedSVD(n_components=n_components)
    reduced_array = tsvd.fit_transform(X)
    reduced_array = reduced_array.T
    reduced_array = tsvd.fit_transform(reduced_array)
    reduced_array = reduced_array.T
    return reduced_array

# %%
reduced_X = np.empty((3131, 28, 28))
for i, row in enumerate(new_X):
    temp = row
    temp = S_V_D(temp)
    reduced_X[i] = temp

# %%
X_train, X_test, y_train, y_test = train_test_split(reduced_X, Y, test_size=0.2)

# %%
model = Sequential()
model.add(Bidirectional(LSTM(24, input_shape=(new_X.shape[1:]),activation='tanh',return_sequences=True)))
model.add(Dropout(0.5))
model.add(LSTM(32,activation='tanh'))
model.add(Dropout(0.5))
model.add(Dense(16,activation='tanh'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=[tf.keras.metrics.BinaryAccuracy()])

# %%
Records = pd.DataFrame(columns=['Go-Ids', 'F1-Score','Accuracy'])
for column in y_train.columns:
    temp = []
    a = y_train[column]
    b = y_test[column]
    #sample_weights = compute_sample_weight(class_weight='balanced', y=a)
    #history = model.fit(X_train,a,epochs=10,sample_weight =sample_weights)
    history = model.fit(X_train,a,epochs=10)
    y_pred = model.predict(X_test)
    y_pred = [0 if value < 0.5 else 1 for value in y_pred]
    temp.append(column)
    temp.append(f1_score(b, y_pred, average='binary'))
    temp.append(accuracy_score(b,y_pred))
    Records.loc[len(Records)] = temp
# Out:
# Epoch 1/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6081 - binary_accuracy: 0.6729
# Epoch 2/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5596 - binary_accuracy: 0.7416
# Epoch 3/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5616 - binary_accuracy: 0.7380
# Epoch 4/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5572 - binary_accuracy: 0.7388
# Epoch 5/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5610 - binary_accuracy: 0.7416
# Epoch 6/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5565 - binary_accuracy: 0.7468
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5595 - binary_accuracy: 0.7440
# Epoch 8/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5561 - binary_accuracy: 0.7452
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5582 - binary_accuracy: 0.7424
# Epoch 10/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5596 - binary_accuracy: 0.7420
# 20/20 [==============================] - 0s 4ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6870 - binary_accuracy: 0.5603
# Epoch 2/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6079 - binary_accuracy: 0.6218
# Epoch 3/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6017 - binary_accuracy: 0.6250
# Epoch 4/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5999 - binary_accuracy: 0.6302
# Epoch 5/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5989 - binary_accuracy: 0.6314
# Epoch 6/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5995 - binary_accuracy: 0.6214
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5966 - binary_accuracy: 0.6230
# Epoch 8/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5945 - binary_accuracy: 0.6358
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5953 - binary_accuracy: 0.6294
# Epoch 10/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5956 - binary_accuracy: 0.6258
# 20/20 [==============================] - 0s 4ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6814 - binary_accuracy: 0.6034
# Epoch 2/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6553 - binary_accuracy: 0.6174
# Epoch 3/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6564 - binary_accuracy: 0.6170
# Epoch 4/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6556 - binary_accuracy: 0.6174
# Epoch 5/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6550 - binary_accuracy: 0.6166
# Epoch 6/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6523 - binary_accuracy: 0.6174
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6523 - binary_accuracy: 0.6170
# Epoch 8/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6518 - binary_accuracy: 0.6162
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6519 - binary_accuracy: 0.6170
# Epoch 10/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6498 - binary_accuracy: 0.6190
# 20/20 [==============================] - 0s 4ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5666 - binary_accuracy: 0.7440
# Epoch 2/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.5637 - binary_accuracy: 0.7440
# Epoch 3/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5603 - binary_accuracy: 0.7440
# Epoch 4/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5573 - binary_accuracy: 0.7440
# Epoch 5/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5568 - binary_accuracy: 0.7440
# Epoch 6/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5605 - binary_accuracy: 0.7440
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5594 - binary_accuracy: 0.7440
# Epoch 8/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5578 - binary_accuracy: 0.7440
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5601 - binary_accuracy: 0.7440
# Epoch 10/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5560 - binary_accuracy: 0.7440
# 20/20 [==============================] - 0s 4ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6283 - binary_accuracy: 0.7081
# Epoch 2/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5818 - binary_accuracy: 0.7224
# Epoch 3/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5806 - binary_accuracy: 0.7256
# Epoch 4/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5806 - binary_accuracy: 0.7264
# Epoch 5/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5815 - binary_accuracy: 0.7248
# Epoch 6/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5795 - binary_accuracy: 0.7272
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5811 - binary_accuracy: 0.7232
# Epoch 8/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5800 - binary_accuracy: 0.7244
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5797 - binary_accuracy: 0.7308
# Epoch 10/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5799 - binary_accuracy: 0.7248
# 20/20 [==============================] - 0s 3ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.7285 - binary_accuracy: 0.4920
# Epoch 2/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6922 - binary_accuracy: 0.5188
# Epoch 3/10
# 79/79 [==============================] - 1s 11ms/step - loss: 0.6932 - binary_accuracy: 0.5172
# Epoch 4/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6914 - binary_accuracy: 0.5152
# Epoch 5/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6907 - binary_accuracy: 0.5228
# Epoch 6/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6888 - binary_accuracy: 0.5367
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6897 - binary_accuracy: 0.5451
# Epoch 8/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6910 - binary_accuracy: 0.5351
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6861 - binary_accuracy: 0.5359
# Epoch 10/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6879 - binary_accuracy: 0.5447
# 20/20 [==============================] - 0s 3ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.6120 - binary_accuracy: 0.7057
# Epoch 2/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5420 - binary_accuracy: 0.7480
# Epoch 3/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5287 - binary_accuracy: 0.7480
# Epoch 4/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5257 - binary_accuracy: 0.7480
# Epoch 5/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5236 - binary_accuracy: 0.7480
# Epoch 6/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.5245 - binary_accuracy: 0.7480
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5214 - binary_accuracy: 0.7480
# Epoch 8/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5211 - binary_accuracy: 0.7480
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5228 - binary_accuracy: 0.7480
# Epoch 10/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5217 - binary_accuracy: 0.7480
# 20/20 [==============================] - 0s 3ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.5516 - binary_accuracy: 0.7424
# Epoch 2/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.5484 - binary_accuracy: 0.7424
# Epoch 3/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.5468 - binary_accuracy: 0.7424
# Epoch 4/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.5480 - binary_accuracy: 0.7424
# Epoch 5/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.5471 - binary_accuracy: 0.7424
# Epoch 6/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5466 - binary_accuracy: 0.7424
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5483 - binary_accuracy: 0.7424
# Epoch 8/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5485 - binary_accuracy: 0.7424
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5467 - binary_accuracy: 0.7424
# Epoch 10/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5470 - binary_accuracy: 0.7424
# 20/20 [==============================] - 0s 4ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.4862 - binary_accuracy: 0.7780
# Epoch 2/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.4877 - binary_accuracy: 0.7780
# Epoch 3/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.4860 - binary_accuracy: 0.7780
# Epoch 4/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.4884 - binary_accuracy: 0.7780
# Epoch 5/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.4882 - binary_accuracy: 0.7780
# Epoch 6/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.4861 - binary_accuracy: 0.7780
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.4840 - binary_accuracy: 0.7780
# Epoch 8/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.4852 - binary_accuracy: 0.7780
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.4843 - binary_accuracy: 0.7780
# Epoch 10/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.4839 - binary_accuracy: 0.7780
# 20/20 [==============================] - 0s 4ms/step
# Epoch 1/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.6075 - binary_accuracy: 0.7432
# Epoch 2/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5465 - binary_accuracy: 0.7540
# Epoch 3/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.5443 - binary_accuracy: 0.7580
# Epoch 4/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5437 - binary_accuracy: 0.7536
# Epoch 5/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.5462 - binary_accuracy: 0.7528
# Epoch 6/10
# 79/79 [==============================] - 1s 10ms/step - loss: 0.5458 - binary_accuracy: 0.7548
# Epoch 7/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5434 - binary_accuracy: 0.7600
# Epoch 8/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5426 - binary_accuracy: 0.7584
# Epoch 9/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5411 - binary_accuracy: 0.7616
# Epoch 10/10
# 79/79 [==============================] - 1s 9ms/step - loss: 0.5419 - binary_accuracy: 0.7632
# 20/20 [==============================] - 0s 4ms/step

# %%
Records = Records.merge(Names, left_on='Go-Ids', right_on='go_go_id')
Records = Records.drop(columns=['go_go_id'])

# %%
Records =  Records.iloc[:,[0,3,1,2]]

# %%
Records =  Records.sort_values(by=['F1-Score','Accuracy'], ascending=False)
Records
# Out:
#        Go-Ids                          go_function  F1-Score  Accuracy
# 0  GO:0003674                   molecular_function  0.847619  0.744817
# 5  GO:0008150                   biological_process  0.685535  0.521531
# 4  GO:0005575                   cellular_component  0.253394  0.736842
# 9  GO:0110165           cellular anatomical entity  0.247525  0.757576
# 1  GO:0003824                   catalytic activity  0.033473  0.631579
# 8  GO:0071704  organic substance metabolic process  0.000000  0.767145
# 6  GO:0008152                    metabolic process  0.000000  0.732057
# 3  GO:0005515                      protein binding  0.000000  0.724083
# 7  GO:0009987                     cellular process  0.000000  0.724083
# 2  GO:0005488                              binding  0.000000  0.591707
